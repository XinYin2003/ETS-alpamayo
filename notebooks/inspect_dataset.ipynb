# %%
# %load_ext autoreload
# %autoreload 2

# %%
from alpamayo_r1.data.pai import PAIDataset

pai_local_dir = "/path/to/PAI"
pai_dataset = PAIDataset(
    local_dir=pai_local_dir,
    chunk_ids="0-9",
    include_extr_intr=True,
)

# %%
from alpamayo_r1.visualization.viz import visualize_data

sample = pai_dataset[0]

visualize_data(
    sample["image_frames"],
    ego_future_xyz_gt=sample["ego_future_xyz"],
    extr=sample["extr"],
    intr=sample["intr"],
)
